# %%
from numpy import *
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("Data.csv",index_col=0)
df
# Out:
#       NaCl  MgCl2
# Time
# 0      0.0    0.0
# 3      0.8    1.0
# 6      1.6    2.0
# 9      2.2    2.8
# 12     3.2    3.8
# 15     4.2    4.8
# 18     5.2    5.6
# 21     6.2    6.4
# 24     7.2    7.4
# 27     8.0    8.2
# 30     8.8    9.2

# %%
plt.plot(df.index,df["NaCl"] ,'-o')
plt.plot(df.index,df["MgCl2"],'-o')
plt.grid('on')
plt.legend(["NaCl",r"$\text{MgCl}_2$"])
plt.xlabel("Time (min)")
plt.ylabel(r"Level of $\text{H}_2$")
plt.title("Electrolysis")
# Out:
# Text(0.5, 1.0, 'Electrolysis')
